# %% [raw]
# All information is coming from:
#
# Harrison Kinsley & Daniel Kukieła. Neural Networks from Scratch (NNFS). https://nnfs.io

# %% [raw]
# Chapter 1 - Introducing Neural Networks

# %% [raw]
# A deep NN is a NN wich has two or more hidden layers
#
# Supervised learning - Pre-established and labeled data
#
#     Classification and regression are Supervised Learning
#
# Unsupervised Learning - Machine finds structure in data without knowing the labels/classes ahead of time
#
# There is also Reinforcement Learning and semi supervised learning (not covered in this book)

# %% [raw]
# What is a NN?
#
# A NN iis inspired by the human brain containing Neurons, Activations, and Interconnectivity
#
# When many neurons are interconnected they can produce relationships that outperform other ML methods

# %% [markdown]
# ![image.png](attachment:a2c1933e-79d9-40bb-8e74-214387983ee6.png)

# %% [raw]
# Parameters are what are adjusted or learned to produce the correct output
#
# NN's can be considered black boxes since we dont always know why they came to their conclusions but we have an idea of how they do
#
# Dense layer is one of the most common layers
#
# Dense layers are fully connected to every neuron of the next layer
#
#     this means that the output of a dense layer becomes the input of all the next neurons
#
# Each neuron has a weight and bias with it which are both trainable
#
# The purpose of the bias is to offset the output postively or negatively
#
# These parameters (weights / bias) can be thought of knobs which can be tune to fit our data
#
# Output = weight * input + bias
#
# We then want to send an activation to this neuron
#     If the neruons output value fires or if it shouldnt
#         Simple example:
#                  if output is greater than 0 send a 1 (fires)
#                  if output is less than 0 send a 0 (does not fire)
#
# for example:
#
# output = activation(output)
#
# Example of an activation function
#     ReLU - Rectified Linear

# %% [raw]
# Usually you preprocces data before you pass it in to a NN
#
# Examples of preproccesing
#     Normalization
#     Scaling
#
#     Input need to be in numeric form
#
#     Normal to have your data scaled between 0 to 1

# %% [raw]
# The end goal of a NN is to adjust their weights / biases so when it is applied to an unseen data example as input it produces the desired output
#
# One issue that can occur is overfitting
#     overfitting is when the network memorizes the training data instead of actually understanding the underlying input-output dependencies
#
# Generalization is when the model fits the data instead of memorizing it
#
# you will know if your model has generalized if it can accuratly perform on unseen data

# %% [raw]
# To train a NN
#
# We calculate how wrong the model was using algoritmns to calculate the error (called loss)
#
# Then this loss is used to gradualy update the parameters so over iterations of the data the NN becomes less wrong
